# %% [markdown]
# ## Computing and plotting wind speed with earthkit (GRIB)

# %% [markdown]
# In this notebook we will demonstrate how to:
#
# * extract wind components on the 500 hPa pressure level
# * compute the wind speed
# * change the GRIB header in the resulting fields
# * plot the results
#
# Let's import the necessary packages:

# %%
import earthkit.data
import earthkit.maps
import numpy as np
import ipywidgets as widgets
from ipywidgets import interactive_output
from datetime import datetime, timedelta

# %% [markdown]
# First, we **retrieve** the wind forecast data from **MARS** for a set of pressure levels and forecast steps on a 5x5 degree **regular latlon grid**.

# %%
yesterday = (datetime.now() - timedelta(1)).strftime('%Y-%m-%d')
g = earthkit.data.from_source("mars",type='fc', 
                date = yesterday, 
                time = 0,
                param = ['u','v'], 
                levelist = ['500', '1000'], 
                levType = 'pl',
                step = [0, 6, 12, 18],            
                grid = [5, 5])
# Out:
# mars - INFO   - 20240410.122503 - Welcome to MARS
# mars - INFO   - 20240410.122503 - MARS_HOME=/home/usxa/.marsrc/home
# mars - INFO   - 20240410.122503 - MARS Client build stamp: 20240410103252
# mars - INFO   - 20240410.122503 - MARS Client bundle version: 6.33.18.0
# mars - INFO   - 20240410.122503 - MARS Client version: 20240410
# mars - INFO   - 20240410.122503 - package mars-client version: 6.33.18
# mars - INFO   - 20240410.122503 - package mir version: 1.19.1
# mars - INFO   - 20240410.122503 - package odc version: 1.5.0
# mars - INFO   - 20240410.122503 - package fdb version: 5.11.30
# mars - INFO   - 20240410.122503 - package metkit version: 1.11.7
# mars - INFO   - 20240410.122503 - package eckit version: 1.25.2
# mars - INFO   - 20240410.122503 - package eccodes version: 2.34.1
# retrieve,
# type=fc,
# date=2024-04-09,
# time=0,
# param=u/v,
# levelist=500/1000,
# levType=pl,
# step=0/6/12/18,
# grid=5/5,
# target="/tmp/tmp2b3kb1af/mars-retriever-9444ce7acd4931a48170dd7bcec3933090d56e82fc5859f780757533e59e75ca.cache.tmp"
# mars - INFO   - 20240410.122503 - Automatic split on dates is on
#
# mars - INFO   - 20240410.122503 - Processing request 1
#
# RETRIEVE,
#     CLASS      = OD,
#     TYPE       = FC,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = PL,
#     LEVELIST   = 500/1000,
#     PARAM      = 131/132,
#     TIME       = 0000,
#     STEP       = 0/6/12/18,
#     DOMAIN     = G,
#     TARGET     = "/tmp/tmp2b3kb1af/mars-retriever-9444ce7acd4931a48170dd7bcec3933090d56e82fc5859f780757533e59e75ca.cache.tmp",
#     RESOL      = AUTO,
#     GRID       = 5/5,
#     DATE       = 20240409
#
# mars - INFO   - 20240410.122503 - Requesting 16 fields
# mars - WARN   - 20240410.122503 - Local socket address resolve to local IP: [127.0.0.1]
# mars - WARN   - 20240410.122503 - Using hostname for callback address instead: [test-webinar]
# mars - INFO   - 20240410.122503 - Calling mars on 'fdbprod.ecmwf.int', local port is 42869
# mars - INFO   - 20240410.122503 - Callback at address 136.156.133.165, port 42869
# mars - INFO   - 20240410.122504 - Mars client is on test-webinar (136.156.133.165) 42869
# mars - INFO   - 20240410.122504 - Mars server is on aa6-210.ecmwf.int (10.100.64.210) 60643
# mars - INFO   - 20240410.122504 - Server task is 459 [ATOS FDB]
# mars - INFO   - 20240410.122504 - Retrieving from FDB [ATOS FDB]
# mars - INFO   - 20240410.122504 - Looking up FDB indexes: 0.053509 second elapsed, 0.046454 second cpu [ATOS FDB]
# mars - INFO   - 20240410.122504 - Transfering 52486368 bytes
# mars - INFO   - 20240410.122504 - Deriving U and V from vorticity and divergence
# mars - INFO   - 20240410.122504 - ShToGridded: loading Legendre coefficients '/tmp/cache/mir/legendre/4/local-T35-GaussianN18-OPT4189816c2e.leg'
# mars - INFO   - 20240410.122504 - 16 fields retrieved from 'ATOS FDB'
# mars - INFO   - 20240410.122504 - 16 fields have been interpolated on 'test-webinar'
# mars - INFO   - 20240410.122504 - Request time:  wall: 1 sec
# mars - INFO   - 20240410.122504 -   Read from network: 50.05 Mbyte(s) in < 1 sec [194.19 Mbyte/sec]
# mars - INFO   - 20240410.122504 -   Writing to target file: 86.25 Kbyte(s) in < 1 sec [317.84 Mbyte/sec]
# mars - INFO   - 20240410.122504 - Memory used: 204.55 Mbyte(s)
# mars - INFO   - 20240410.122504 - No errors reported

# %% [markdown]
# The result is a [GribFieldList](https://earthkit-data.readthedocs.io/en/latest/_api/data/readers/grib/index/index.html#data.readers.grib.index.GribFieldList), which is earthkit's own class to represent GRIB data. We can check the contents of our GribFieldList with [describe()](https://earthkit-data.readthedocs.io/en/latest/_api/data/readers/grib/index/index.html#data.readers.grib.index.GribFieldList.describe), which shows us high level content of the grib.

# %% [markdown]
# Alternatively, we can also retrieve similar data from the Copernicus Climate Data Store using the cdsapi

# %%
now = datetime.now()
g = earthkit.data.from_source(
    'cds',
    'reanalysis-era5-pressure-levels',
    {
        'product_type': 'reanalysis',
        'format': 'grib',
        'variable': [
            'u_component_of_wind', 'v_component_of_wind',
        ],
        'pressure_level': [
            '500', '1000',
        ],
        'year': now.year - 1,
        'month': now.month,
        'day': now.day,
        'time': [
            '00:00', '06:00', '12:00',
            '18:00',
        ],
    },
)
# Out:
# 2024-04-10 12:25:04,866 INFO Welcome to the CDS
# 2024-04-10 12:25:04,867 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2024-04-10 12:25:05,024 INFO Request is queued
# 2024-04-10 12:25:06,033 INFO Request is running
# 2024-04-10 12:25:07,538 INFO Request is completed
# 2024-04-10 12:25:07,539 INFO Downloading https://download-0000-clone.copernicus-climate.eu/cache-compute-0000/cache/data6/adaptor.mars.internal-1712751905.364721-30289-13-adc3b594-a928-4f1a-9d00-df077d35a7b1.grib to /tmp/tmp2b3kb1af/cds-retriever-fd614bad5c38fc1ddce630bcd7ba55e433f6b297fe99d68ed62bead2f3b5efc6.grib.tmp (31.7M)
# 2024-04-10 12:25:07,931 INFO Download rate 80.8M/s

# %%
g.describe()
# Out:
# <style type="text/css">
# #T_54395 th {
#   text-align: left;
# }
# #T_54395_row0_col0, #T_54395_row0_col1, #T_54395_row0_col2, #T_54395_row0_col3, #T_54395_row0_col4, #T_54395_row0_col5, #T_54395_row0_col6, #T_54395_row0_col7, #T_54395_row0_col8, #T_54395_row1_col0, #T_54395_row1_col1, #T_54395_row1_col2, #T_54395_row1_col3, #T_54395_row1_col4, #T_54395_row1_col5, #T_54395_row1_col6, #T_54395_row1_col7, #T_54395_row1_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_54395">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54395_level0_col0" class="col_heading level0 col0" >level</th>
#       <th id="T_54395_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_54395_level0_col2" class="col_heading level0 col2" >time</th>
#       <th id="T_54395_level0_col3" class="col_heading level0 col3" >step</th>
#       <th id="T_54395_level0_col4" class="col_heading level0 col4" >paramId</th>
#       <th id="T_54395_level0_col5" class="col_heading level0 col5" >class</th>
#       <th id="T_54395_level0_col6" class="col_heading level0 col6" >stream</th>
#       <th id="T_54395_level0_col7" class="col_heading level0 col7" >type</th>
#       <th id="T_54395_level0_col8" class="col_heading level0 col8" >experimentVersionNumber</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shortName</th>
#       <th class="index_name level1" >typeOfLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54395_level0_row0" class="row_heading level0 row0" >u</th>
#       <th id="T_54395_level1_row0" class="row_heading level1 row0" >isobaricInhPa</th>
#       <td id="T_54395_row0_col0" class="data row0 col0" >1000,500</td>
#       <td id="T_54395_row0_col1" class="data row0 col1" >20230410</td>
#       <td id="T_54395_row0_col2" class="data row0 col2" >0,1800,...</td>
#       <td id="T_54395_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_54395_row0_col4" class="data row0 col4" >131</td>
#       <td id="T_54395_row0_col5" class="data row0 col5" >ea</td>
#       <td id="T_54395_row0_col6" class="data row0 col6" >oper</td>
#       <td id="T_54395_row0_col7" class="data row0 col7" >an</td>
#       <td id="T_54395_row0_col8" class="data row0 col8" >0001</td>
#     </tr>
#     <tr>
#       <th id="T_54395_level0_row1" class="row_heading level0 row1" >v</th>
#       <th id="T_54395_level1_row1" class="row_heading level1 row1" >isobaricInhPa</th>
#       <td id="T_54395_row1_col0" class="data row1 col0" >1000,500</td>
#       <td id="T_54395_row1_col1" class="data row1 col1" >20230410</td>
#       <td id="T_54395_row1_col2" class="data row1 col2" >0,1800,...</td>
#       <td id="T_54395_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_54395_row1_col4" class="data row1 col4" >132</td>
#       <td id="T_54395_row1_col5" class="data row1 col5" >ea</td>
#       <td id="T_54395_row1_col6" class="data row1 col6" >oper</td>
#       <td id="T_54395_row1_col7" class="data row1 col7" >an</td>
#       <td id="T_54395_row1_col8" class="data row1 col8" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Next, we **filter** the 500 hPa wind components using the **[sel()](https://earthkit-data.readthedocs.io/en/latest/_api/data/readers/grib/index/index.html#data.readers.grib.index.GribFieldList.sel)** function.

# %%
u = g.sel(shortName='u', level=500)
v = g.sel(shortName='v', level=500)

# %% [markdown]
# Having extracted the wind components we **compute** the wind speed fields using standard numpy arithmetic. We also generate new metadata for the fields with the right parameter for wind speed (ws)

# %%
ws_md = [f.metadata().override(shortName="ws") for f in u]
ws_values = [np.sqrt(i.values*i.values + j.values*j.values) for i, j in zip(u,v)]
ws = earthkit.data.FieldList.from_numpy(ws_values, ws_md)
ws.describe()
# Out:
# <style type="text/css">
# #T_0c29c th {
#   text-align: left;
# }
# #T_0c29c_row0_col0, #T_0c29c_row0_col1, #T_0c29c_row0_col2, #T_0c29c_row0_col3, #T_0c29c_row0_col4, #T_0c29c_row0_col5, #T_0c29c_row0_col6, #T_0c29c_row0_col7, #T_0c29c_row0_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_0c29c">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c29c_level0_col0" class="col_heading level0 col0" >level</th>
#       <th id="T_0c29c_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_0c29c_level0_col2" class="col_heading level0 col2" >time</th>
#       <th id="T_0c29c_level0_col3" class="col_heading level0 col3" >step</th>
#       <th id="T_0c29c_level0_col4" class="col_heading level0 col4" >paramId</th>
#       <th id="T_0c29c_level0_col5" class="col_heading level0 col5" >class</th>
#       <th id="T_0c29c_level0_col6" class="col_heading level0 col6" >stream</th>
#       <th id="T_0c29c_level0_col7" class="col_heading level0 col7" >type</th>
#       <th id="T_0c29c_level0_col8" class="col_heading level0 col8" >experimentVersionNumber</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shortName</th>
#       <th class="index_name level1" >typeOfLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c29c_level0_row0" class="row_heading level0 row0" >ws</th>
#       <th id="T_0c29c_level1_row0" class="row_heading level1 row0" >isobaricInhPa</th>
#       <td id="T_0c29c_row0_col0" class="data row0 col0" >500</td>
#       <td id="T_0c29c_row0_col1" class="data row0 col1" >20230410</td>
#       <td id="T_0c29c_row0_col2" class="data row0 col2" >0,1800,...</td>
#       <td id="T_0c29c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0c29c_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_0c29c_row0_col5" class="data row0 col5" >ea</td>
#       <td id="T_0c29c_row0_col6" class="data row0 col6" >oper</td>
#       <td id="T_0c29c_row0_col7" class="data row0 col7" >an</td>
#       <td id="T_0c29c_row0_col8" class="data row0 col8" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Finally, we **plot** the first windspeed field using automatic contouring and title settings.

# %%
style = earthkit.maps.Style(colors='viridis_r', levels=[10,15,20,25,30,40,50,60,80,100])
earthkit.maps.quickplot(ws[0],style=style)

# %% [markdown]
# We can also use ipywidgets to animate the plotting of the GribFieldList

# %%
def get_plot(index):
    style = earthkit.maps.Style(colors='viridis_r', levels=[10,15,20,25,30,40,50,60,80,100])
    earthkit.maps.quickplot(ws[index],style=style)
play = widgets.Play(
    value=0,
    min=0,
    max=len(ws)-1,
    step=1,
    interval=1000,
    description="Press play",
    disabled=False
)
interactive_plot = interactive_output(get_plot, {'index': play})
field_slider = widgets.IntSlider(max=len(ws)-1, description="Frame:")
speed_slider = widgets.IntSlider(min=1, max=4, description="Speed:")
speed_slider.observe(lambda change: setattr(play, 'interval', 1000 * speed_slider.value), 'value')
widgets.jslink((play, 'value'), (field_slider, 'value'))
widgets.VBox([interactive_plot, field_slider, speed_slider, play])
# Out:
# VBox(children=(Output(), IntSlider(value=0, description='Frame:', max=3), IntSlider(value=1, description='Spee…

# %% [markdown]
# This notebook is adapted from [the example in Metview documentation](https://metview.readthedocs.io/en/latest/examples/compute_wind_speed.html).
